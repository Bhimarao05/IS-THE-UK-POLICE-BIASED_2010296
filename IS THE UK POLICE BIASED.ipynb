# %%
#importing the os. system()function excutes a command, print any output
#of the command to the consule, and return the exit code of the command.
import os

#the glob moudule is used to retrive files/pathnames matching a specific pattren
import glob

#simply imports the library the current namespace, but rather than using the name pandas 
# its instructed to use pd 
import pandas as pd
path =r'C:\Users\HP\Documents\888-2_29April\UK_POLIS\2020-06'
filenames = glob.glob(path + "/*.csv")

# %%
#Deep first search for tree traversal on graph or tree data structures.
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# %%
#result for the first search
dfs
# Out:
# [                          Type                       Date  \
#  0                Person search  2020-06-01T00:00:00+00:00
#  1    Person and Vehicle search  2020-06-01T00:00:00+00:00
#  2                Person search  2020-06-01T00:30:00+00:00
#  3                Person search  2020-06-01T00:40:00+00:00
#  4                Person search  2020-06-01T00:50:00+00:00
#  ..                         ...                        ...
#  950              Person search  2020-06-30T20:25:00+00:00
#  951              Person search  2020-06-30T20:30:00+00:00
#  952              Person search  2020-06-30T20:39:00+00:00
#  953              Person search  2020-06-30T21:55:00+00:00
#  954              Person search  2020-06-30T21:55:00+00:00
#
#       Part of a policing operation  Policing operation   Latitude  Longitude  \
#  0                             NaN                 NaN        NaN        NaN
#  1                             NaN                 NaN        NaN        NaN
# ...

# %%
#last data frame set creation
big_frame = pd.concat(dfs, ignore_index=True)
dfs = pd.DataFrame(big_frame)

# %%
dfs
# Out:
#                             Type                       Date  \
# 0                  Person search  2020-06-01T00:00:00+00:00
# 1      Person and Vehicle search  2020-06-01T00:00:00+00:00
# 2                  Person search  2020-06-01T00:30:00+00:00
# 3                  Person search  2020-06-01T00:40:00+00:00
# 4                  Person search  2020-06-01T00:50:00+00:00
# ...                          ...                        ...
# 65242  Person and Vehicle search  2020-06-28T23:00:00+00:00
# 65243  Person and Vehicle search  2020-06-28T23:00:00+00:00
# 65244              Person search  2020-06-28T23:00:00+00:00
# 65245  Person and Vehicle search  2020-06-28T23:00:00+00:00
# 65246              Person search  2020-06-29T23:00:00+00:00
#
#       Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                              NaN                 NaN        NaN        NaN
# 1                              NaN                 NaN        NaN        NaN
# ...

# %%
#Creation of an independent and dependent data framework
df=pd.DataFrame()

# %%
#independent variable which doesnot depend on any thing as we need them for data visualization 
df["Self-defined ethnicity"]=dfs["Self-defined ethnicity"]
df["Officer-defined ethnicity"]=dfs["Officer-defined ethnicity"]
df["Outcome"]=dfs["Outcome"]

# %%
df
# Out:
#                                   Self-defined ethnicity  \
# 0                                                    NaN
# 1                                                    NaN
# 2                        Other ethnic group - Not stated
# 3                        Other ethnic group - Not stated
# 4      Black/African/Caribbean/Black British - Caribbean
# ...                                                  ...
# 65242                    Other ethnic group - Not stated
# 65243  White - English/Welsh/Scottish/Northern Irish/...
# 65244  White - English/Welsh/Scottish/Northern Irish/...
# 65245  White - English/Welsh/Scottish/Northern Irish/...
# 65246  White - English/Welsh/Scottish/Northern Irish/...
#
#       Officer-defined ethnicity                       Outcome
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN  A no further action disposal
# ...

# %%
df1=df["Outcome"].fillna("A no further action disposal")

# %%
df2=df["Officer-defined ethnicity"].fillna("White")

# %%
df3=df["Self-defined ethnicity"].fillna("A no further action disposal")

# %%
dff=pd.DataFrame()

# %%
dff["Self-defined ethnicity"]=df1
dff["Officer-defined ethnicity"]=df2
dff["Outcome"]=df3

# %%
dff
# Out:
#              Self-defined ethnicity Officer-defined ethnicity  \
# 0      A no further action disposal                     White
# 1      A no further action disposal                     White
# 2      A no further action disposal                     White
# 3      A no further action disposal                     Asian
# 4      A no further action disposal                     Black
# ...                             ...                       ...
# 65242  A no further action disposal                     White
# 65243                        Arrest                     White
# 65244  A no further action disposal                     White
# 65245  A no further action disposal                     White
# 65246                        Arrest                     White
#
#                                                  Outcome
# 0                           A no further action disposal
# 1                           A no further action disposal
# ...

# %%
dfm = dff.groupby('Officer-defined ethnicity').count()

# %%
dfm
# Out:
#                            Self-defined ethnicity  Outcome
# Officer-defined ethnicity
# Asian                                        8800     8800
# Black                                       12945    12945
# Mixed                                         185      185
# Other                                        1948     1948
# White                                       41369    41369

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 25))
dfm.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Officer-defined ethnicity'>

# %%
import seaborn as sns
import numpy as np

# %%
#scatterplot for data visulaization
sns.lmplot(dfm.columns[0], dfm.columns[1], data=dfm, fit_reg=False)

## Histogram
sns.displot(data, bins=20, kde=False, rug=True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
